# %% [markdown]
# ## Some math in python
#
# Complete the code in the functions math1-math12 below.

# %%
import numpy as np

# %%
def math1(mat):
  """
  Square each value in mat separatly and return the result
  """
  out = np.power(mat, 2)
  return out

# %%
mat = np.arange(16).reshape((4, 4))
print(math1(mat))
# Out:
# [[  0   1   4   9]
#  [ 16  25  36  49]
#  [ 64  81 100 121]
#  [144 169 196 225]]

# %% [markdown]
# ### Expected output
# [[  0   1   4   9]
#  [ 16  25  36  49]
#  [ 64  81 100 121]
#  [144 169 196 225]]

# %%
def math2(mat):
  """
  Return the sum of all the values in mat
  """
  out = np.sum(mat)
  return out

# %%
mat = np.arange(16).reshape((4, 4))
print(math2(mat))
# Out:
# 120

# %% [markdown]
# ### Expected output
#
# 120

# %%
def math3(mat):
  """
  Return the sum of each row in mat
  """
  out = np.sum(mat, axis=1)
  return out

# %%
mat = np.arange(16).reshape((4, 4))
print(math3(mat))
# Out:
# [ 6 22 38 54]

# %% [markdown]
# ### Expected output
#
# [ 6 22 38 54]

# %%
def math4(mat):
  """
  Return a scaled version of mat, so that it sums to 1
  """
  out = mat / np.sum(mat)
  return out

# %%
mat = np.arange(16).reshape((4, 4))
print(math4(mat))
# Out:
# [[0.         0.00833333 0.01666667 0.025     ]
#  [0.03333333 0.04166667 0.05       0.05833333]
#  [0.06666667 0.075      0.08333333 0.09166667]
#  [0.1        0.10833333 0.11666667 0.125     ]]

# %% [markdown]
# ### Expected output
#
# [[ 0.          0.00833333  0.01666667  0.025     ]
#  [ 0.03333333  0.04166667  0.05        0.05833333]
#  [ 0.06666667  0.075       0.08333333  0.09166667]
#  [ 0.1         0.10833333  0.11666667  0.125     ]]

# %%
def math5(mat, v):
  """
  Element-wise multiply each column in mat with vector v
  newaxis or .reshape
  """
  out = np.multiply(mat, v[:, np.newaxis])
  return out

# %%
mat = np.arange(16).reshape((4, 4))
vec = np.arange(4)
print(math5(mat,vec))
# Out:
# [[ 0  0  0  0]
#  [ 4  5  6  7]
#  [16 18 20 22]
#  [36 39 42 45]]

# %% [markdown]
# ### Expected output
#
# [[ 0  0  0  0]
#  [ 4  5  6  7]
#  [16 18 20 22]
#  [36 39 42 45]]

# %%
def math6(mat, v):
  """
  Element-wise multiply each row in mat with vector v
  """
  out = np.multiply(mat, v[np.newaxis, :])
  return out

# %%
mat = np.arange(16).reshape((4, 4))
vec = np.arange(4)
print(math6(mat,vec))
# Out:
# [[ 0  1  4  9]
#  [ 0  5 12 21]
#  [ 0  9 20 33]
#  [ 0 13 28 45]]

# %% [markdown]
# ### Expected output
#
# [[ 0  1  4  9]
#  [ 0  5 12 21]
#  [ 0  9 20 33]
#  [ 0 13 28 45]]

# %%
def math7(mat, v):
  """
  Matrix multiply matrix m with vector v
  """
  out = np.matmul(mat, v)
  return out

# %%
mat = np.arange(16).reshape((4, 4))
vec = np.arange(4)
print(math7(mat,vec))
# Out:
# [14 38 62 86]

# %% [markdown]
# ### Expected output
#
# [14 38 62 86]

# %%
def math8(mat):
  """
  Return the inverse matrix of mat
  """
  return np.linalg.inv(mat)

# %%
mat = np.array([[4, 7], [2, 6]])
print(math8(mat))
# Out:
# None

# %% [markdown]
# ### Expected output
#
# [[ 0.6 -0.7]
#  [-0.2  0.4]]

# %%
def math9(mat, v):
  """
  Return the dot-product between each row in mat and v
  dot or matmul
  """
  out = np.dot(mat, v)
  return out

# %%
mat = np.arange(16).reshape((4, 4))
vec = np.arange(4)
print(math9(mat,vec))
# Out:
# [14 38 62 86]

# %% [markdown]
# ### Expected output
#
# [14 38 62 86]

# %%
def math10(mat, v):
  """
  Return the dot-product between each column in mat and v
  """
  return np.dot(mat.transpose(), v)

# %%
mat = np.arange(16).reshape((4, 4))
vec = np.arange(4)
print(math10(mat,vec))
# Out:
# [56 62 68 74]

# %% [markdown]
# ### Expected output
#
# [56 62 68 74]

# %%
def math11(mat1, mat2):
  """
  Return the dot-products between each corresponding (same index) column in mat1 and mat2
  """
  out = np.einsum("ij,ij->j", mat1, mat2)
  return out

# %%
mat = np.arange(16).reshape((4, 4))
print(math11(mat,mat.T))
# Out:
# [ 56 174 324 506]

# %% [markdown]
# ### Expected value
#
# [ 56 174 324 506]
